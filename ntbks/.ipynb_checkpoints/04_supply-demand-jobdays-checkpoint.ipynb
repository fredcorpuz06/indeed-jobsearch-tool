# %% [markdown]
# ## Sample for DecisionTree Regressor

# %%
# Import the necessary modules and libraries
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.model_selection import train_test_split

# %%
# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16)) ## noise

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1234)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (53, 1) (27, 1) (53,) (27,)

# %%
plt.figure()
plt.scatter(X_train, y_train, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.show()

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=2, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
# Predict
# X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# %%
# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")

plt.plot(X_test, y_1, color="cornflowerblue",label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
# Out:
# Text(0.5,0,'data')
# Text(0,0.5,'target')
# Text(0.5,1,'Decision Tree Regression')

# %%
mean_squared_error(y_test,y_1) ## y1 is better
mean_squared_error(y_test,y_2)
# Out:
# 0.17102516305981008
# 0.21190290074813709

# %%
r2_score(y_test,y_1) ## y1 is better
r2_score(y_test,y_2)
# Out:
# 0.5935248160351929
# 0.4963707736144466

# %%
explained_variance_score(y_test,y_1) ## y1 is better
explained_variance_score(y_test,y_2)
# Out:
# 0.5972381824830901
# 0.4972290356677773

# %%
# from sklearn.externals.six import StringIO  
# from IPython.display import Image  
from sklearn.tree import export_graphviz
# import pydotplus
import graphviz

# %%
## automatic creation
# dot_data = StringIO()

# export_graphviz(regr_1, out_file=dot_data,  
#                 filled=True, rounded=True,
#                 special_characters=True)

# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  

# Image(graph.create_png())

# %%
dot_data = export_graphviz(regr_2, out_file=None)
graph = graphviz.Source(dot_data)
print(graph.source)
# filename = graph.render(filename='img/graph')
# print(filename)
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="X[0] <= 3.149\nmse = 0.583\nsamples = 53\nvalue = 0.22"] ;
# 1 [label="X[0] <= 0.337\nmse = 0.237\nsamples = 37\nvalue = 0.621"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="X[0] <= 0.046\nmse = 0.239\nsamples = 5\nvalue = -0.19"] ;
# 1 -> 2 ;
# 3 [label="mse = 0.0\nsamples = 1\nvalue = -1.149"] ;
# 2 -> 3 ;
# 4 [label="X[0] <= 0.193\nmse = 0.01\nsamples = 4\nvalue = 0.05"] ;
# 2 -> 4 ;
# 5 [label="X[0] <= 0.117\nmse = 0.0\nsamples = 3\nvalue = 0.108"] ;
# 4 -> 5 ;
# 6 [label="mse = 0.0\nsamples = 2\nvalue = 0.094"] ;
# 5 -> 6 ;
# 7 [label="mse = 0.0\nsamples = 1\nvalue = 0.137"] ;
# 5 -> 7 ;
# 8 [label="mse = -0.0\nsamples = 1\nvalue = -0.124"] ;
# 4 -> 8 ;
# 9 [label="X[0] <= 2.101\nmse = 0.118\nsamples = 32\nvalue = 0.747"] ;
# 1 -> 9 ;
# 10 [label="X[0] <= 0.699\nmse = 0.097\nsamples = 24\nvalue = 0.817"] ;
# 9 -> 10 ;
# 11 [label="X[0] <= 0.583\nmse = 0.008\nsamples = 5\nvalue = 0.557"] ;
# ...

# %%
## With color customization
# # Visualize data
# dot_data = export_graphviz(clf,
#                                 feature_names=data_feature_names,
#                                 out_file=None,
#                                 filled=True,
#                                 rounded=True)
# graph = pydotplus.graph_from_dot_data(dot_data)
 
# colors = ('turquoise', 'orange')
# edges = collections.defaultdict(list)
 
# for edge in graph.get_edge_list():
#     edges[edge.get_source()].append(int(edge.get_destination()))
 
# for edge in edges:
#     edges[edge].sort()    
#     for i in range(2):
#         dest = graph.get_node(str(edges[edge][i]))[0]
#         dest.set_fillcolor(colors[i])
 
# graph.write_png('tree.png')

# %% [markdown]
# ## Cleaning data from jobdays

# %%
import pickle
with open('../data/mini-clean.pickle', 'rb') as handle:
    df = pickle.load(handle)

# %%
print(df.shape, df.columns)
# Out:
# (1763530, 28) Index(['date', 'companyId', 'jobId', 'country', 'stateProvince', 'city',
#        'avgOverallRating', 'numReviews', 'industry', 'normTitle',
#        'normTitleCategory', 'descriptionCharacterLength',
#        'descriptionWordCount', 'experienceRequired', 'estimatedSalary',
#        'salaryCurrency', 'jobLanguage', 'supervisingJob', 'licenseRequiredJob',
#        'educationRequirement', 'jobAgeDays', 'clicks', 'localClicks', 'month',
#        'day', 'clicks_log', 'localClicks_log', 'numReviews_log'],
#       dtype='object')

# %%
df.companyId.value_counts().head()
# Out:
# company00090    32113
# company00025     5402
# company00003     5295
# company00211     4470
# company00047     4043
# Name: companyId, dtype: int64

# %%
df.jobId.value_counts().head()
# Out:
# job0031529    23
# job0122077    22
# job0033569    21
# job0116620    21
# job0127311    21
# Name: jobId, dtype: int64

# %%
# mask = df.companyId == 'company00090'
mask = df.jobId == 'job0031529'

# %%
mask = np.array(df.jobId == 'job0031529') | np.array(df.jobId == 'job0122077') | np.array(df.jobId == 'job0033569')

# %%
jobs3 = df.loc[mask, ['date','companyId','jobId', 'jobAgeDays']]
jobs3.sort_values(by=['jobAgeDays'])
# jobs3.jobId.value_counts()
# Out:
#                date     companyId       jobId  jobAgeDays
# 112423   2017-01-29  company21127  job0033569           4
# 914283   2017-01-30  company21127  job0033569           5
# 1354045  2017-05-31  company02410  job0122077           5
# 1738390  2017-03-26  company00041  job0031529           6
# 1277667  2017-06-02  company02410  job0122077           7
# 700187   2017-02-01  company21127  job0033569           7
# 1313361  2017-06-03  company02410  job0122077           8
# 591125   2017-06-05  company02410  job0122077          10
# 481828   2017-06-06  company02410  job0122077          11
# 1428861  2017-02-06  company21127  job0033569          12
# 865545   2017-06-07  company02410  job0122077          12
# 1121677  2017-04-02  company00041  job0031529          13
# 165592   2017-04-03  company00041  job0031529          14
# 470290   2017-02-08  company21127  job0033569          14
# 885694   2017-04-04  company00041  job0031529          15
# ...

# %%
## What is the max number of days a job was up?
jobs3.groupby(['jobId']).agg({'jobAgeDays' : 'max'})
# Out:
#             jobAgeDays
# jobId
# job0031529          70
# job0033569          98
# job0122077          91

# %%
# How many unique per column?
jobs3.apply('nunique')
# Out:
# date          62
# companyId      3
# jobId          3
# jobAgeDays    52
# dtype: int64

# %%
## How many unique jobs per company?
jobs3.groupby(['companyId']).agg({'jobId': 'nunique'})
# Out:
#               jobId
# companyId
# company00041      1
# company02410      1
# company21127      1

# %%
finalJDays = df.loc[:, ['date', 'companyId', 'jobId', 'jobAgeDays']].groupby(['companyId', 'jobId'], as_index=False).aggregate('count')
finalJDays.head()
finalJDays.tail()
# Out:
#       companyId       jobId  date  jobAgeDays
# 0  company00001  job0003468     1           1
# 1  company00001  job0013295     2           2
# 2  company00001  job0018408     6           6
# 3  company00001  job0032246     2           2
# 4  company00001  job0049452     4           4
#            companyId       jobId  date  jobAgeDays
# 639691  company99994  job0670882     5           5
# 639692  company99995  job0236116     1           1
# 639693  company99996  job0236117     1           1
# 639694  company99997  job0236118     1           1
# 639695  company99998  job0236119     1           1

# %%
finalJDays = df.loc[mask, ['date', 'companyId', 'jobId', 'jobAgeDays']].groupby(['companyId', 'jobId'], as_index=False).aggregate('count')
finalJDays.head()
finalJDays.tail()
# Out:
#       companyId       jobId  date  jobAgeDays
# 0  company00041  job0031529    23          23
#       companyId       jobId  date  jobAgeDays
# 0  company00041  job0031529    23          23
